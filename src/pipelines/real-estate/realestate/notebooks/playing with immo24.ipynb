# %%
import os
import sys
import socket

import sys,uuid,datetime
from pyspark.sql import SparkSession
from pyspark import SparkConf, SparkContext

key = os.environ["MINIO_ROOT_USER"]
secret = os.environ["MINIO_ROOT_PASSWORD"]
endpoint = os.environ["MINIO_SECRET_ENDPOINT"]
endpoint = "http://127.0.0.1:9000"
print(endpoint)

#sc.stop()

spark = SparkSession.builder \
.master("k8s://https://kubernetes.docker.internal:6443") \
.appName("playing_with_immo24") \
.config("spark.hadoop.fs.s3a.access.key", key) \
.config("spark.hadoop.fs.s3a.secret.key", secret) \
.config("spark.hadoop.fs.s3a.endpoint", endpoint) \
.config("spark.hadoop.fs.s3a.path.style.access", "true") \
.config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
.config("spark.jars.packages", "io.delta:delta-core_2.12:0.7.0,org.apache.hadoop:hadoop-aws:3.2.0,com.amazonaws:aws-java-sdk-bundle:1.11.375") \
.config("spark.delta.logStore.class", "org.apache.spark.sql.delta.storage.S3SingleDriverLogStore") \
.config('spark.submit.deployMode', 'client') \
.config("spark.kubernetes.container.image", "spark:spark-docker") \
.config("spark.kubernetes.pyspark.pythonVersion", "3") \
.config("spark.kubernetes.authenticate.driver.serviceAccountName", "default") \
.config("spark.executor.instances", "1") \
.config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
.config("spark.kubernetes.executor.request.cores","0.5") \
.config("spark.kubernetes.executor.limit.cores","1") \
.config("jupyterService.jupyterPort", "30888") \
.config("serviceAccount", "spark") \
.config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
.config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
.getOrCreate()

#.config("spark.driver.host", "10.1.2.104") \
#.config("spark.driver.port", "4040") \

sc = spark.sparkContext
#sc._conf.getAll()
# Out:
# http://127.0.0.1:9000

# %%
import pandas as pd
import json, ijson #made for big files which cannot be handled in memory

#visualisations
import folium
from folium import plugins
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-80a22df03298> in <module>
# ----> 1 import pandas as pd
#       2 import json, ijson #made for big files which cannot be handled in memory
#       3
#       4 #visualisations
#       5 import folium
#
# ModuleNotFoundError: No module named 'pandas'

# %%
path_BE = "s3a://real-estate/staging/201031_Bern_buy_0_flat.gz" 
path_SO = "s3a://real-estate/staging/201031_Solothurn_buy_0_flat.gz"
df_SO = spark.read.json(path_SO)
df = spark.read.json(path_BE)

# %%
from pyspark.sql.types import ArrayType, StructType
from pyspark.sql.functions import col, explode_outer

#Flatten array of structs and structs
def flatten(df):

   # compute Complex Fields (Lists and Structs) in Schema   
   complex_fields = dict([(field.name, field.dataType)
                             for field in df.schema.fields
                             if (type(field.dataType) == ArrayType or type(field.dataType) == StructType) and field.name.startswith('propertyDetails')])
   
   #print(complex_fields) 
   while len(complex_fields)!=0:    
        
      col_name=list(complex_fields.keys())[0]
      #print ("Processing :"+col_name+" Type : "+str(type(complex_fields[col_name])))
       
      if col_name in ["propertyDetails_images","propertyDetails_pdfs","propertyDetails_commuteTimes_defaultPois_transportations"]:
            #remove and skip next part
            df=df.drop(col_name)
      else:
          # if StructType then convert all sub element to columns.
          # i.e. flatten structs
          if (type(complex_fields[col_name]) == StructType):
             expanded = [col(col_name+'.'+k).alias(col_name+'_'+k) for k in [ n.name for n in  complex_fields[col_name]]]
             df=df.select("*", *expanded).drop(col_name)


          # if ArrayType then add the Array Elements as Rows using the explode function
          # i.e. explode Arrays
          elif (type(complex_fields[col_name]) == ArrayType):
             df=df.withColumn(col_name,explode_outer(col_name))
    
      # recompute remaining Complex Fields in Schema       
      complex_fields = dict([(field.name, field.dataType)
                             for field in df.schema.fields
                             if type(field.dataType) == ArrayType or  type(field.dataType) == StructType])
      #print(complex_fields)
      #print(df.count())

   return df

df_flatten_BE=flatten(df)
df_flatten_SO=flatten(df_SO)

# %%
df_flatten_BE.printSchema()
df_flatten_BE.count()
# Out:
# root
#  |-- propertyDetails_accountId: long (nullable = true)
#  |-- propertyDetails_availableFrom: string (nullable = true)
#  |-- propertyDetails_availableFromFormatted: string (nullable = true)
#  |-- propertyDetails_cityId: long (nullable = true)
#  |-- propertyDetails_cityName: string (nullable = true)
#  |-- propertyDetails_contactFormTypeId: long (nullable = true)
#  |-- propertyDetails_countryId: long (nullable = true)
#  |-- propertyDetails_description: string (nullable = true)
#  |-- propertyDetails_geoAccuracy: long (nullable = true)
#  |-- propertyDetails_hasNewBuildingProject: boolean (nullable = true)
#  |-- propertyDetails_hasVirtualTour: boolean (nullable = true)
#  |-- propertyDetails_id: long (nullable = true)
#  |-- propertyDetails_isBuyRent: string (nullable = true)
#  |-- propertyDetails_isHighlighted: boolean (nullable = true)
#  |-- propertyDetails_isNew: boolean (nullable = true)
#  |-- propertyDetails_isNewEndDate: string (nullable = true)
#  |-- propertyDetails_isOnline: boolean (nullable = true)
#  |-- propertyDetails_isQualityListing: boolean (nullable = true)
#  |-- propertyDetails_isTopListing: boolean (nullable = true)
#  |-- propertyDetails_lastModified: string (nullable = true)
#  |-- propertyDetails_lastPublished: string (nullable = true)
#  |-- propertyDetails_latitude: double (nullable = true)
#  |-- propertyDetails_listingLayout: long (nullable = true)
#  |-- propertyDetails_longitude: double (nullable = true)
#  |-- propertyDetails_msRegionId: long (nullable = true)
#  |-- propertyDetails_municipalityBfsId: long (nullable = true)
#  |-- propertyDetails_municipalityId: long (nullable = true)
#  |-- propertyDetails_municipalityNameFormatted: string (nullable = true)
#  |-- propertyDetails_normalizedPrice: long (nullable = true)
#  |-- propertyDetails_normalizedPriceFormatted: string (nullable = true)
#  |-- propertyDetails_numberOfRooms: double (nullable = true)
#  |-- propertyDetails_numberOfRoomsFormatted: string (nullable = true)
#  |-- propertyDetails_offerTypeId: long (nullable = true)
#  |-- propertyDetails_packageType: long (nullable = true)
#  |-- propertyDetails_price: long (nullable = true)
#  |-- propertyDetails_priceFormatted: string (nullable = true)
#  |-- propertyDetails_priceUnitId: long (nullable = true)
#  |-- propertyDetails_priceUnitLabel: string (nullable = true)
#  |-- propertyDetails_propertyCategoryId: long (nullable = true)
#  |-- propertyDetails_propertyDetailUrl: string (nullable = true)
#  |-- propertyDetails_propertyId: string (nullable = true)
#  |-- propertyDetails_propertyType: string (nullable = true)
#  |-- propertyDetails_propertyTypeId: long (nullable = true)
#  |-- propertyDetails_referenceNo: string (nullable = true)
#  |-- propertyDetails_regionId: long (nullable = true)
#  |-- propertyDetails_searchCity: string (nullable = true)
#  |-- propertyDetails_searchDate: string (nullable = true)
#  |-- propertyDetails_searchDateTime: string (nullable = true)
#  |-- propertyDetails_searchRadius: long (nullable = true)
#  |-- propertyDetails_sellingPrice: long (nullable = true)
#  |-- propertyDetails_sellingPriceFormatted: string (nullable = true)
#  |-- propertyDetails_shortDescription: string (nullable = true)
#  |-- propertyDetails_showContactForm: boolean (nullable = true)
#  |-- propertyDetails_showContactFormAddress: boolean (nullable = true)
#  |-- propertyDetails_state: string (nullable = true)
#  |-- propertyDetails_stateShort: string (nullable = true)
#  |-- propertyDetails_street: string (nullable = true)
#  |-- propertyDetails_surfaceLiving: long (nullable = true)
#  |-- propertyDetails_surfaceLivingFormatted: string (nullable = true)
#  |-- propertyDetails_surfaceUsable: long (nullable = true)
#  |-- propertyDetails_surfaceUsableFormatted: string (nullable = true)
#  |-- propertyDetails_title: string (nullable = true)
#  |-- propertyDetails_url: string (nullable = true)
#  |-- propertyDetails_urlTitle: string (nullable = true)
#  |-- propertyDetails_videoViewingEnabled: boolean (nullable = true)
#  |-- propertyDetails_visitName: string (nullable = true)
#  |-- propertyDetails_visitPhone: string (nullable = true)
#  |-- propertyDetails_visitRemark: string (nullable = true)
#  |-- propertyDetails_zip: string (nullable = true)
#  |-- propertyDetails_zipId: long (nullable = true)
#  |-- viewData_agencyPhoneStatsUrl: string (nullable = true)
#  |-- viewData_allowOnlineApplication: boolean (nullable = true)
#  |-- viewData_areSimilarPropertiesFromSameAdvertiser: boolean (nullable = true)
#  |-- viewData_debtEnforcementLandingPageUrl: string (nullable = true)
#  |-- viewData_detailPrintStatsUrl: string (nullable = true)
#  |-- viewData_detailViewStatsUrl: string (nullable = true)
#  |-- viewData_financingLinkUrl: string (nullable = true)
#  |-- viewData_movingUrl: string (nullable = true)
#  |-- viewData_showAccountProperties: boolean (nullable = true)
#  |-- viewData_showSimilarProperties: boolean (nullable = true)
#  |-- viewData_visitPhoneStatsUrl: string (nullable = true)
#  |-- propertyDetails_agency_companyCity: string (nullable = true)
#  |-- propertyDetails_agency_companyName1: string (nullable = true)
#  |-- propertyDetails_agency_companyName2: string (nullable = true)
#  |-- propertyDetails_agency_companyPhoneBusiness: string (nullable = true)
#  |-- propertyDetails_agency_companyPhoneMobile: string (nullable = true)
#  |-- propertyDetails_agency_companyStreet: string (nullable = true)
#  |-- propertyDetails_agency_companyZip: string (nullable = true)
#  |-- propertyDetails_agency_firstName: string (nullable = true)
#  |-- propertyDetails_agency_gender: string (nullable = true)
#  |-- propertyDetails_agency_isAccountMigrated: boolean (nullable = true)
#  |-- propertyDetails_agency_isGuest: boolean (nullable = true)
#  |-- propertyDetails_agency_lastName: string (nullable = true)
#  |-- propertyDetails_agency_logoUrl: string (nullable = true)
#  |-- propertyDetails_agency_logoUrlDetailPage: string (nullable = true)
#  |-- propertyDetails_agency_nameFormatted: string (nullable = true)
#  |-- propertyDetails_agency_reference: string (nullable = true)
#  |-- propertyDetails_agency_showLogoOnSerp: boolean (nullable = true)
#  |-- propertyDetails_agency_userType: string (nullable = true)
#  |-- propertyDetails_agency_webUrl: string (nullable = true)
#  |-- propertyDetails_attributes_newBuilding: boolean (nullable = true)
#  |-- propertyDetails_attributes_oldBuilding: boolean (nullable = true)
#  |-- propertyDetails_attributes_underBuildingLaws: boolean (nullable = true)
#  |-- propertyDetails_attributes_yearBuilt: long (nullable = true)
#  |-- propertyDetails_attributes_yearRenovated: long (nullable = true)
#  |-- propertyDetails_attributesInside_animalAllowed: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_cellar: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_firePlace: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_nrBathRooms: long (nullable = true)
#  |-- propertyDetails_attributesInside_propView: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_reduit: boolean (nullable = true)
#  |-- propertyDetails_attributesInside_wheelChairAccessible: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_playGround: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propBalcony: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propChildFriendly: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propElevator: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propGarage: boolean (nullable = true)
#  |-- propertyDetails_attributesOutside_propParking: boolean (nullable = true)
#  |-- propertyDetails_attributesSize_floor: long (nullable = true)
#  |-- propertyDetails_attributesSize_floorFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSize_numberOfFloors: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceKindergarten: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceKindergartenFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceMotorway: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceMotorwayFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distancePublicTransport: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distancePublicTransportFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceSchool1: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceSchool1Formatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceSchool2: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceSchool2Formatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceShop: long (nullable = true)
#  |-- propertyDetails_attributesSurrounding_distanceShopFormatted: string (nullable = true)
#  |-- propertyDetails_attributesSurrounding_objectSituation: string (nullable = true)
#  |-- propertyDetails_attributesTechnology_dishWasher: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_isMinergieCertified: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_minergieGeneral: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_propCabletv: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_separateTumbleDryer: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_separateWashingMachine: boolean (nullable = true)
#  |-- propertyDetails_attributesTechnology_steamer: boolean (nullable = true)
#  |-- propertyDetails_videos_description: string (nullable = true)
#  |-- propertyDetails_videos_id: long (nullable = true)
#  |-- propertyDetails_videos_lastModified: string (nullable = true)
#  |-- propertyDetails_videos_remoteId: string (nullable = true)
#  |-- propertyDetails_videos_sortOrder: long (nullable = true)
#  |-- propertyDetails_videos_title: string (nullable = true)
#  |-- propertyDetails_virtualTours_description: string (nullable = true)
#  |-- propertyDetails_virtualTours_id: long (nullable = true)
#  |-- propertyDetails_virtualTours_lastModified: string (nullable = true)
#  |-- propertyDetails_virtualTours_sortOrder: long (nullable = true)
#  |-- propertyDetails_virtualTours_title: string (nullable = true)
#  |-- propertyDetails_virtualTours_url: string (nullable = true)
#  |-- viewData_agencyBusinessImage_description: string (nullable = true)
#  |-- viewData_agencyBusinessImage_id: long (nullable = true)
#  |-- viewData_agencyBusinessImage_lastModified: string (nullable = true)
#  |-- viewData_agencyBusinessImage_originalHeight: long (nullable = true)
#  |-- viewData_agencyBusinessImage_originalWidth: long (nullable = true)
#  |-- viewData_agencyBusinessImage_sortOrder: long (nullable = true)
#  |-- viewData_agencyBusinessImage_title: string (nullable = true)
#  |-- viewData_agencyBusinessImage_url: string (nullable = true)
#  |-- viewData_viewDataWeb_accountPropertiesUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_copyShareUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_fbShareUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_whatsAppShareUrl: string (nullable = true)
#  |-- propertyDetails_commuteTimes_defaultPois_label: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_activeLanguage: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_countImages: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_countPDF: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_country: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_customerType: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_englishVirtualPagePath: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_floorLevel: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasHighlighting: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasToplisting: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasVideoViewing: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasVirtualTour: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_hasYoutube: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_isCooperation: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_isNewBuilding: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_isShortUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listingId: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_availability: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_cantonName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_locationName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_msregion: long (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_propertyType: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_listing_zip: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_livingSpace: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_localVirtualPagePath: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_numberOfRooms: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_offerTypeName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_packageName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_price: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_streetName: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_userCountry: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_userLoggedIn: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_userOrigin: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_gtmData_viewTab: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_description: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_imageHeight: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_imageType: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_imageUrl: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_imageWidth: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_title: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_openGraphData_url: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@context: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_@type: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_availability: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_description: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_image: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_name: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_price: long (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_priceCurrency: string (nullable = true)
#  |-- viewData_viewDataWeb_webView_structuredData_@graph_url: string (nullable = true)
# 20

# %%
insert_columns = '\n, '.join(df_flatten_BE.columns)
#print(insert_columns)

#update_columns = ', trg.'.join(df_flatten_BE.columns).join(' = src.')


update_columns = '\n, '.join(['trg.'+ c +' = src.'+c for c in df_flatten_BE.columns])
print(update_columns)
# Out:
# trg.propertyDetails_accountId = src.propertyDetails_accountId
# , trg.propertyDetails_availableFrom = src.propertyDetails_availableFrom
# , trg.propertyDetails_availableFromFormatted = src.propertyDetails_availableFromFormatted
# , trg.propertyDetails_cityId = src.propertyDetails_cityId
# , trg.propertyDetails_cityName = src.propertyDetails_cityName
# , trg.propertyDetails_contactFormTypeId = src.propertyDetails_contactFormTypeId
# , trg.propertyDetails_countryId = src.propertyDetails_countryId
# , trg.propertyDetails_description = src.propertyDetails_description
# , trg.propertyDetails_geoAccuracy = src.propertyDetails_geoAccuracy
# , trg.propertyDetails_hasNewBuildingProject = src.propertyDetails_hasNewBuildingProject
# , trg.propertyDetails_hasVirtualTour = src.propertyDetails_hasVirtualTour
# , trg.propertyDetails_id = src.propertyDetails_id
# , trg.propertyDetails_isBuyRent = src.propertyDetails_isBuyRent
# , trg.propertyDetails_isHighlighted = src.propertyDetails_isHighlighted
# , trg.propertyDetails_isNew = src.propertyDetails_isNew
# , trg.propertyDetails_isNewEndDate = src.propertyDetails_isNewEndDate
# , trg.propertyDetails_isOnline = src.propertyDetails_isOnline
# , trg.propertyDetails_isQualityListing = src.propertyDetails_isQualityListing
# , trg.propertyDetails_isTopListing = src.propertyDetails_isTopListing
# , trg.propertyDetails_lastModified = src.propertyDetails_lastModified
# , trg.propertyDetails_lastPublished = src.propertyDetails_lastPublished
# , trg.propertyDetails_latitude = src.propertyDetails_latitude
# , trg.propertyDetails_listingLayout = src.propertyDetails_listingLayout
# , trg.propertyDetails_longitude = src.propertyDetails_longitude
# , trg.propertyDetails_msRegionId = src.propertyDetails_msRegionId
# , trg.propertyDetails_municipalityBfsId = src.propertyDetails_municipalityBfsId
# , trg.propertyDetails_municipalityId = src.propertyDetails_municipalityId
# , trg.propertyDetails_municipalityNameFormatted = src.propertyDetails_municipalityNameFormatted
# , trg.propertyDetails_normalizedPrice = src.propertyDetails_normalizedPrice
# , trg.propertyDetails_normalizedPriceFormatted = src.propertyDetails_normalizedPriceFormatted
# , trg.propertyDetails_numberOfRooms = src.propertyDetails_numberOfRooms
# , trg.propertyDetails_numberOfRoomsFormatted = src.propertyDetails_numberOfRoomsFormatted
# , trg.propertyDetails_offerTypeId = src.propertyDetails_offerTypeId
# , trg.propertyDetails_packageType = src.propertyDetails_packageType
# , trg.propertyDetails_price = src.propertyDetails_price
# , trg.propertyDetails_priceFormatted = src.propertyDetails_priceFormatted
# , trg.propertyDetails_priceUnitId = src.propertyDetails_priceUnitId
# , trg.propertyDetails_priceUnitLabel = src.propertyDetails_priceUnitLabel
# , trg.propertyDetails_propertyCategoryId = src.propertyDetails_propertyCategoryId
# , trg.propertyDetails_propertyDetailUrl = src.propertyDetails_propertyDetailUrl
# , trg.propertyDetails_propertyId = src.propertyDetails_propertyId
# , trg.propertyDetails_propertyType = src.propertyDetails_propertyType
# , trg.propertyDetails_propertyTypeId = src.propertyDetails_propertyTypeId
# , trg.propertyDetails_referenceNo = src.propertyDetails_referenceNo
# , trg.propertyDetails_regionId = src.propertyDetails_regionId
# , trg.propertyDetails_searchCity = src.propertyDetails_searchCity
# , trg.propertyDetails_searchDate = src.propertyDetails_searchDate
# , trg.propertyDetails_searchDateTime = src.propertyDetails_searchDateTime
# , trg.propertyDetails_searchRadius = src.propertyDetails_searchRadius
# , trg.propertyDetails_sellingPrice = src.propertyDetails_sellingPrice
# , trg.propertyDetails_sellingPriceFormatted = src.propertyDetails_sellingPriceFormatted
# , trg.propertyDetails_shortDescription = src.propertyDetails_shortDescription
# , trg.propertyDetails_showContactForm = src.propertyDetails_showContactForm
# , trg.propertyDetails_showContactFormAddress = src.propertyDetails_showContactFormAddress
# , trg.propertyDetails_state = src.propertyDetails_state
# , trg.propertyDetails_stateShort = src.propertyDetails_stateShort
# , trg.propertyDetails_street = src.propertyDetails_street
# , trg.propertyDetails_surfaceLiving = src.propertyDetails_surfaceLiving
# , trg.propertyDetails_surfaceLivingFormatted = src.propertyDetails_surfaceLivingFormatted
# , trg.propertyDetails_surfaceUsable = src.propertyDetails_surfaceUsable
# , trg.propertyDetails_surfaceUsableFormatted = src.propertyDetails_surfaceUsableFormatted
# , trg.propertyDetails_title = src.propertyDetails_title
# , trg.propertyDetails_url = src.propertyDetails_url
# , trg.propertyDetails_urlTitle = src.propertyDetails_urlTitle
# , trg.propertyDetails_videoViewingEnabled = src.propertyDetails_videoViewingEnabled
# , trg.propertyDetails_visitName = src.propertyDetails_visitName
# , trg.propertyDetails_visitPhone = src.propertyDetails_visitPhone
# , trg.propertyDetails_visitRemark = src.propertyDetails_visitRemark
# , trg.propertyDetails_zip = src.propertyDetails_zip
# , trg.propertyDetails_zipId = src.propertyDetails_zipId
# , trg.viewData_agencyPhoneStatsUrl = src.viewData_agencyPhoneStatsUrl
# , trg.viewData_allowOnlineApplication = src.viewData_allowOnlineApplication
# , trg.viewData_areSimilarPropertiesFromSameAdvertiser = src.viewData_areSimilarPropertiesFromSameAdvertiser
# , trg.viewData_debtEnforcementLandingPageUrl = src.viewData_debtEnforcementLandingPageUrl
# , trg.viewData_detailPrintStatsUrl = src.viewData_detailPrintStatsUrl
# , trg.viewData_detailViewStatsUrl = src.viewData_detailViewStatsUrl
# , trg.viewData_financingLinkUrl = src.viewData_financingLinkUrl
# , trg.viewData_movingUrl = src.viewData_movingUrl
# , trg.viewData_showAccountProperties = src.viewData_showAccountProperties
# , trg.viewData_showSimilarProperties = src.viewData_showSimilarProperties
# , trg.viewData_visitPhoneStatsUrl = src.viewData_visitPhoneStatsUrl
# , trg.propertyDetails_agency_companyCity = src.propertyDetails_agency_companyCity
# , trg.propertyDetails_agency_companyName1 = src.propertyDetails_agency_companyName1
# , trg.propertyDetails_agency_companyName2 = src.propertyDetails_agency_companyName2
# , trg.propertyDetails_agency_companyPhoneBusiness = src.propertyDetails_agency_companyPhoneBusiness
# , trg.propertyDetails_agency_companyPhoneMobile = src.propertyDetails_agency_companyPhoneMobile
# , trg.propertyDetails_agency_companyStreet = src.propertyDetails_agency_companyStreet
# , trg.propertyDetails_agency_companyZip = src.propertyDetails_agency_companyZip
# , trg.propertyDetails_agency_firstName = src.propertyDetails_agency_firstName
# , trg.propertyDetails_agency_gender = src.propertyDetails_agency_gender
# , trg.propertyDetails_agency_isAccountMigrated = src.propertyDetails_agency_isAccountMigrated
# , trg.propertyDetails_agency_isGuest = src.propertyDetails_agency_isGuest
# , trg.propertyDetails_agency_lastName = src.propertyDetails_agency_lastName
# , trg.propertyDetails_agency_logoUrl = src.propertyDetails_agency_logoUrl
# , trg.propertyDetails_agency_logoUrlDetailPage = src.propertyDetails_agency_logoUrlDetailPage
# , trg.propertyDetails_agency_nameFormatted = src.propertyDetails_agency_nameFormatted
# , trg.propertyDetails_agency_reference = src.propertyDetails_agency_reference
# , trg.propertyDetails_agency_showLogoOnSerp = src.propertyDetails_agency_showLogoOnSerp
# , trg.propertyDetails_agency_userType = src.propertyDetails_agency_userType
# , trg.propertyDetails_agency_webUrl = src.propertyDetails_agency_webUrl
# , trg.propertyDetails_attributes_newBuilding = src.propertyDetails_attributes_newBuilding
# , trg.propertyDetails_attributes_oldBuilding = src.propertyDetails_attributes_oldBuilding
# , trg.propertyDetails_attributes_underBuildingLaws = src.propertyDetails_attributes_underBuildingLaws
# , trg.propertyDetails_attributes_yearBuilt = src.propertyDetails_attributes_yearBuilt
# , trg.propertyDetails_attributes_yearRenovated = src.propertyDetails_attributes_yearRenovated
# , trg.propertyDetails_attributesInside_animalAllowed = src.propertyDetails_attributesInside_animalAllowed
# , trg.propertyDetails_attributesInside_cellar = src.propertyDetails_attributesInside_cellar
# , trg.propertyDetails_attributesInside_firePlace = src.propertyDetails_attributesInside_firePlace
# , trg.propertyDetails_attributesInside_nrBathRooms = src.propertyDetails_attributesInside_nrBathRooms
# , trg.propertyDetails_attributesInside_propView = src.propertyDetails_attributesInside_propView
# , trg.propertyDetails_attributesInside_reduit = src.propertyDetails_attributesInside_reduit
# , trg.propertyDetails_attributesInside_wheelChairAccessible = src.propertyDetails_attributesInside_wheelChairAccessible
# , trg.propertyDetails_attributesOutside_playGround = src.propertyDetails_attributesOutside_playGround
# , trg.propertyDetails_attributesOutside_propBalcony = src.propertyDetails_attributesOutside_propBalcony
# , trg.propertyDetails_attributesOutside_propChildFriendly = src.propertyDetails_attributesOutside_propChildFriendly
# , trg.propertyDetails_attributesOutside_propElevator = src.propertyDetails_attributesOutside_propElevator
# , trg.propertyDetails_attributesOutside_propGarage = src.propertyDetails_attributesOutside_propGarage
# , trg.propertyDetails_attributesOutside_propParking = src.propertyDetails_attributesOutside_propParking
# , trg.propertyDetails_attributesSize_floor = src.propertyDetails_attributesSize_floor
# , trg.propertyDetails_attributesSize_floorFormatted = src.propertyDetails_attributesSize_floorFormatted
# , trg.propertyDetails_attributesSize_numberOfFloors = src.propertyDetails_attributesSize_numberOfFloors
# , trg.propertyDetails_attributesSurrounding_distanceKindergarten = src.propertyDetails_attributesSurrounding_distanceKindergarten
# , trg.propertyDetails_attributesSurrounding_distanceKindergartenFormatted = src.propertyDetails_attributesSurrounding_distanceKindergartenFormatted
# , trg.propertyDetails_attributesSurrounding_distanceMotorway = src.propertyDetails_attributesSurrounding_distanceMotorway
# , trg.propertyDetails_attributesSurrounding_distanceMotorwayFormatted = src.propertyDetails_attributesSurrounding_distanceMotorwayFormatted
# , trg.propertyDetails_attributesSurrounding_distancePublicTransport = src.propertyDetails_attributesSurrounding_distancePublicTransport
# , trg.propertyDetails_attributesSurrounding_distancePublicTransportFormatted = src.propertyDetails_attributesSurrounding_distancePublicTransportFormatted
# , trg.propertyDetails_attributesSurrounding_distanceSchool1 = src.propertyDetails_attributesSurrounding_distanceSchool1
# , trg.propertyDetails_attributesSurrounding_distanceSchool1Formatted = src.propertyDetails_attributesSurrounding_distanceSchool1Formatted
# , trg.propertyDetails_attributesSurrounding_distanceSchool2 = src.propertyDetails_attributesSurrounding_distanceSchool2
# , trg.propertyDetails_attributesSurrounding_distanceSchool2Formatted = src.propertyDetails_attributesSurrounding_distanceSchool2Formatted
# , trg.propertyDetails_attributesSurrounding_distanceShop = src.propertyDetails_attributesSurrounding_distanceShop
# , trg.propertyDetails_attributesSurrounding_distanceShopFormatted = src.propertyDetails_attributesSurrounding_distanceShopFormatted
# , trg.propertyDetails_attributesSurrounding_objectSituation = src.propertyDetails_attributesSurrounding_objectSituation
# , trg.propertyDetails_attributesTechnology_dishWasher = src.propertyDetails_attributesTechnology_dishWasher
# , trg.propertyDetails_attributesTechnology_isMinergieCertified = src.propertyDetails_attributesTechnology_isMinergieCertified
# , trg.propertyDetails_attributesTechnology_minergieGeneral = src.propertyDetails_attributesTechnology_minergieGeneral
# , trg.propertyDetails_attributesTechnology_propCabletv = src.propertyDetails_attributesTechnology_propCabletv
# , trg.propertyDetails_attributesTechnology_separateTumbleDryer = src.propertyDetails_attributesTechnology_separateTumbleDryer
# , trg.propertyDetails_attributesTechnology_separateWashingMachine = src.propertyDetails_attributesTechnology_separateWashingMachine
# , trg.propertyDetails_attributesTechnology_steamer = src.propertyDetails_attributesTechnology_steamer
# , trg.propertyDetails_videos_description = src.propertyDetails_videos_description
# , trg.propertyDetails_videos_id = src.propertyDetails_videos_id
# , trg.propertyDetails_videos_lastModified = src.propertyDetails_videos_lastModified
# , trg.propertyDetails_videos_remoteId = src.propertyDetails_videos_remoteId
# , trg.propertyDetails_videos_sortOrder = src.propertyDetails_videos_sortOrder
# , trg.propertyDetails_videos_title = src.propertyDetails_videos_title
# , trg.propertyDetails_virtualTours_description = src.propertyDetails_virtualTours_description
# , trg.propertyDetails_virtualTours_id = src.propertyDetails_virtualTours_id
# , trg.propertyDetails_virtualTours_lastModified = src.propertyDetails_virtualTours_lastModified
# , trg.propertyDetails_virtualTours_sortOrder = src.propertyDetails_virtualTours_sortOrder
# , trg.propertyDetails_virtualTours_title = src.propertyDetails_virtualTours_title
# , trg.propertyDetails_virtualTours_url = src.propertyDetails_virtualTours_url
# , trg.viewData_agencyBusinessImage_description = src.viewData_agencyBusinessImage_description
# , trg.viewData_agencyBusinessImage_id = src.viewData_agencyBusinessImage_id
# , trg.viewData_agencyBusinessImage_lastModified = src.viewData_agencyBusinessImage_lastModified
# , trg.viewData_agencyBusinessImage_originalHeight = src.viewData_agencyBusinessImage_originalHeight
# , trg.viewData_agencyBusinessImage_originalWidth = src.viewData_agencyBusinessImage_originalWidth
# , trg.viewData_agencyBusinessImage_sortOrder = src.viewData_agencyBusinessImage_sortOrder
# , trg.viewData_agencyBusinessImage_title = src.viewData_agencyBusinessImage_title
# , trg.viewData_agencyBusinessImage_url = src.viewData_agencyBusinessImage_url
# , trg.viewData_viewDataWeb_accountPropertiesUrl = src.viewData_viewDataWeb_accountPropertiesUrl
# , trg.viewData_viewDataWeb_copyShareUrl = src.viewData_viewDataWeb_copyShareUrl
# , trg.viewData_viewDataWeb_fbShareUrl = src.viewData_viewDataWeb_fbShareUrl
# , trg.viewData_viewDataWeb_whatsAppShareUrl = src.viewData_viewDataWeb_whatsAppShareUrl
# , trg.propertyDetails_commuteTimes_defaultPois_label = src.propertyDetails_commuteTimes_defaultPois_label
# , trg.viewData_viewDataWeb_webView_gtmData_activeLanguage = src.viewData_viewDataWeb_webView_gtmData_activeLanguage
# , trg.viewData_viewDataWeb_webView_gtmData_countImages = src.viewData_viewDataWeb_webView_gtmData_countImages
# , trg.viewData_viewDataWeb_webView_gtmData_countPDF = src.viewData_viewDataWeb_webView_gtmData_countPDF
# , trg.viewData_viewDataWeb_webView_gtmData_country = src.viewData_viewDataWeb_webView_gtmData_country
# , trg.viewData_viewDataWeb_webView_gtmData_customerType = src.viewData_viewDataWeb_webView_gtmData_customerType
# , trg.viewData_viewDataWeb_webView_gtmData_englishVirtualPagePath = src.viewData_viewDataWeb_webView_gtmData_englishVirtualPagePath
# , trg.viewData_viewDataWeb_webView_gtmData_floorLevel = src.viewData_viewDataWeb_webView_gtmData_floorLevel
# , trg.viewData_viewDataWeb_webView_gtmData_hasHighlighting = src.viewData_viewDataWeb_webView_gtmData_hasHighlighting
# , trg.viewData_viewDataWeb_webView_gtmData_hasToplisting = src.viewData_viewDataWeb_webView_gtmData_hasToplisting
# , trg.viewData_viewDataWeb_webView_gtmData_hasVideoViewing = src.viewData_viewDataWeb_webView_gtmData_hasVideoViewing
# , trg.viewData_viewDataWeb_webView_gtmData_hasVirtualTour = src.viewData_viewDataWeb_webView_gtmData_hasVirtualTour
# , trg.viewData_viewDataWeb_webView_gtmData_hasYoutube = src.viewData_viewDataWeb_webView_gtmData_hasYoutube
# , trg.viewData_viewDataWeb_webView_gtmData_isCooperation = src.viewData_viewDataWeb_webView_gtmData_isCooperation
# , trg.viewData_viewDataWeb_webView_gtmData_isNewBuilding = src.viewData_viewDataWeb_webView_gtmData_isNewBuilding
# , trg.viewData_viewDataWeb_webView_gtmData_isShortUrl = src.viewData_viewDataWeb_webView_gtmData_isShortUrl
# , trg.viewData_viewDataWeb_webView_gtmData_listingId = src.viewData_viewDataWeb_webView_gtmData_listingId
# , trg.viewData_viewDataWeb_webView_gtmData_listing_availability = src.viewData_viewDataWeb_webView_gtmData_listing_availability
# , trg.viewData_viewDataWeb_webView_gtmData_listing_cantonName = src.viewData_viewDataWeb_webView_gtmData_listing_cantonName
# , trg.viewData_viewDataWeb_webView_gtmData_listing_locationName = src.viewData_viewDataWeb_webView_gtmData_listing_locationName
# , trg.viewData_viewDataWeb_webView_gtmData_listing_msregion = src.viewData_viewDataWeb_webView_gtmData_listing_msregion
# , trg.viewData_viewDataWeb_webView_gtmData_listing_propertyType = src.viewData_viewDataWeb_webView_gtmData_listing_propertyType
# , trg.viewData_viewDataWeb_webView_gtmData_listing_zip = src.viewData_viewDataWeb_webView_gtmData_listing_zip
# , trg.viewData_viewDataWeb_webView_gtmData_livingSpace = src.viewData_viewDataWeb_webView_gtmData_livingSpace
# , trg.viewData_viewDataWeb_webView_gtmData_localVirtualPagePath = src.viewData_viewDataWeb_webView_gtmData_localVirtualPagePath
# , trg.viewData_viewDataWeb_webView_gtmData_numberOfRooms = src.viewData_viewDataWeb_webView_gtmData_numberOfRooms
# , trg.viewData_viewDataWeb_webView_gtmData_offerTypeName = src.viewData_viewDataWeb_webView_gtmData_offerTypeName
# , trg.viewData_viewDataWeb_webView_gtmData_packageName = src.viewData_viewDataWeb_webView_gtmData_packageName
# , trg.viewData_viewDataWeb_webView_gtmData_price = src.viewData_viewDataWeb_webView_gtmData_price
# , trg.viewData_viewDataWeb_webView_gtmData_streetName = src.viewData_viewDataWeb_webView_gtmData_streetName
# , trg.viewData_viewDataWeb_webView_gtmData_userCountry = src.viewData_viewDataWeb_webView_gtmData_userCountry
# , trg.viewData_viewDataWeb_webView_gtmData_userLoggedIn = src.viewData_viewDataWeb_webView_gtmData_userLoggedIn
# , trg.viewData_viewDataWeb_webView_gtmData_userOrigin = src.viewData_viewDataWeb_webView_gtmData_userOrigin
# , trg.viewData_viewDataWeb_webView_gtmData_viewTab = src.viewData_viewDataWeb_webView_gtmData_viewTab
# , trg.viewData_viewDataWeb_webView_openGraphData_description = src.viewData_viewDataWeb_webView_openGraphData_description
# , trg.viewData_viewDataWeb_webView_openGraphData_imageHeight = src.viewData_viewDataWeb_webView_openGraphData_imageHeight
# , trg.viewData_viewDataWeb_webView_openGraphData_imageType = src.viewData_viewDataWeb_webView_openGraphData_imageType
# , trg.viewData_viewDataWeb_webView_openGraphData_imageUrl = src.viewData_viewDataWeb_webView_openGraphData_imageUrl
# , trg.viewData_viewDataWeb_webView_openGraphData_imageWidth = src.viewData_viewDataWeb_webView_openGraphData_imageWidth
# , trg.viewData_viewDataWeb_webView_openGraphData_title = src.viewData_viewDataWeb_webView_openGraphData_title
# , trg.viewData_viewDataWeb_webView_openGraphData_url = src.viewData_viewDataWeb_webView_openGraphData_url
# , trg.viewData_viewDataWeb_webView_structuredData_@context = src.viewData_viewDataWeb_webView_structuredData_@context
# , trg.viewData_viewDataWeb_webView_structuredData_@graph_@type = src.viewData_viewDataWeb_webView_structuredData_@graph_@type
# , trg.viewData_viewDataWeb_webView_structuredData_@graph_availability = src.viewData_viewDataWeb_webView_structuredData_@graph_availability
# , trg.viewData_viewDataWeb_webView_structuredData_@graph_description = src.viewData_viewDataWeb_webView_structuredData_@graph_description
# , trg.viewData_viewDataWeb_webView_structuredData_@graph_image = src.viewData_viewDataWeb_webView_structuredData_@graph_image
# , trg.viewData_viewDataWeb_webView_structuredData_@graph_name = src.viewData_viewDataWeb_webView_structuredData_@graph_name
# , trg.viewData_viewDataWeb_webView_structuredData_@graph_price = src.viewData_viewDataWeb_webView_structuredData_@graph_price
# , trg.viewData_viewDataWeb_webView_structuredData_@graph_priceCurrency = src.viewData_viewDataWeb_webView_structuredData_@graph_priceCurrency
# , trg.viewData_viewDataWeb_webView_structuredData_@graph_url = src.viewData_viewDataWeb_webView_structuredData_@graph_url

# %%
from functools import reduce
from pyspark.sql import DataFrame

dfs = []
dfs.append(df_flatten_BE)
dfs.append(df_flatten_SO)

#doesn work with dataframes with different schemas
#df_all = reduce(DataFrame.unionAll, dfs)

# %%
from functools import reduce
from pyspark.sql import DataFrame

prop_s3_coordinates = ["s3a://real-estate/staging/201031_Bern_buy_0_flat.gz", "s3a://real-estate/staging/201031_Solothurn_buy_0_flat.gz"]

dfs = []
for path in prop_s3_coordinates:
    dfs.append(spark.read.json(path))

df_all = reduce(DataFrame.unionAll, dfs)

# %%
#df_flatten.select("propertyDetails_id", "propertyDetails_normalizedPrice").show()
#df_flatten.select("id", "normalizedPrice").show()
df_flatten.createOrReplaceTempView("flatten")

# %%
spark.sql("SELECT propertyDetails_cityName, count(*) FROM flatten GROUP BY propertyDetails_cityName").show()
# Out:
# +------------------------+--------+
# |propertyDetails_cityName|count(1)|
# +------------------------+--------+
# |                    Bern|      20|
# +------------------------+--------+

# %%
#map_SO = folium.Map(location=[47.03303, 7.8], zoom_start=12)
#map_SO

#marker_cluster = folium.MarkerCluster().add_to(map_SO)
#from folium.plugins import MarkerCluster

stops_map = folium.Map(location=[47.03303, 7.8], zoom_start=12)
marker_cluster = MarkerCluster().add_to(stops_map)
for name, row in df.iloc[:1000].iterrows():
    folium.Marker([row["propertyDetails_longitude"], row["propertyDetails_latitude"]], popup=row["propertyDetails_title"]).add_to(marker_cluster)
stops_map.create_map('stops.html')
stops_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-54ca6c87fd06> in <module>
#       6
#       7 stops_map = folium.Map(location=[47.03303, 7.8], zoom_start=12)
# ----> 8 marker_cluster = MarkerCluster().add_to(stops_map)
#       9 for name, row in df.iloc[:1000].iterrows():
#      10     folium.Marker([row["propertyDetails_longitude"], row["propertyDetails_latitude"]], popup=row["propertyDetails_title"]).add_to(marker_cluster)
#
# NameError: name 'MarkerCluster' is not defined
